# %%
import math

e = math.e
print(e)
# Out:
# 2.718281828459045

# %%
import pandas as pd

print()

data = pd.read_csv('Euler data.csv', sep=';', decimal='.')

data['euler'] = e*100

data[:200].plot(x='Capitalizaciones', figsize=(15,10))
